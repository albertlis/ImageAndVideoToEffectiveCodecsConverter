# %%
import shutil
import subprocess
from pathlib import Path

# %%
dir_name = 'Wrak_Race'
src_path = Path(rf'F:\Zdjęcia\{dir_name}')
dst_path = Path(rf'D:\Windows\Pulpit\Zdjęcia\heif\{dir_name}_heif')

for file in src_path.iterdir():
    if file.suffix.lower() in {'.mp4', '.mov', '.mts'}:
        dst_file = dst_path / f"{file.stem}.mp4"
        # if not dst_file.exists():
        #     dst_file = dst_file.with_stem(dst_file.stem.upper().replace(' ', ''))
        if file.name == 'WP_20170420_21_02_28_Pro.mp4':
            continue
        assert dst_file.exists(), f'{dst_file.resolve()} not exists'
        out_file = dst_file.with_stem(f"{dst_file.stem}_fixed")
        # if not dst_file.exists():
        #     continue
        call_str = f'ffmpeg -i {file.resolve()} -i {dst_file} -map 1 ' \
                   f'-map_metadata 0 -c copy {out_file}'

        print(call_str)
        result = subprocess.run(call_str, shell=True, capture_output=True, text=True)
        print(result.stdout)
        print(result.stderr)
        shutil.copystat(file, out_file, follow_symlinks=True)
        dst_file.unlink()
        shutil.move(out_file, dst_file)
# Out:
# ffmpeg -i F:\Zdjęcia\Wrak_Race\20150913_133610.mp4 -i D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_133610.mp4 -map 1 -map_metadata 0 -c copy D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_133610_fixed.mp4
#
# ffmpeg version 6.0-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'F:\ZdjÄ™cia\Wrak_Race\20150913_133610.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:37:58.000000Z
#   Duration: 00:01:47.48, start: 0.000000, bitrate: 3191 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3070 kb/s, 29.93 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:37:58.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:37:58.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_133610.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:37:58.000000Z
#   Duration: 00:01:47.48, start: 0.000000, bitrate: 3191 kb/s
#   Stream #1:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3070 kb/s, 29.93 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:37:58.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #1:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:37:58.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_133610_fixed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:37:58.000000Z
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, q=2-31, 3070 kb/s, 29.93 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:37:58.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 125 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:37:58.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #1:0 -> #0:0 (copy)
#   Stream #1:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=    0 fps=0.0 q=-1.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=N/A
# frame= 3208 fps=0.0 q=-1.0 Lsize=   41933kB time=00:01:47.46 bitrate=3196.6kbits/s speed= 254x
# video:40177kB audio:1641kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.275360%
#
# ffmpeg -i F:\Zdjęcia\Wrak_Race\20150913_134011.mp4 -i D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_134011.mp4 -map 1 -map_metadata 0 -c copy D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_134011_fixed.mp4
#
# ffmpeg version 6.0-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'F:\ZdjÄ™cia\Wrak_Race\20150913_134011.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:40:17.000000Z
#   Duration: 00:00:04.93, start: 0.000000, bitrate: 3096 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3081 kb/s, 29.84 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:40:17.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 123 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:40:17.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_134011.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:40:17.000000Z
#   Duration: 00:00:04.93, start: 0.000000, bitrate: 3096 kb/s
#   Stream #1:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3081 kb/s, 29.84 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:40:17.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #1:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 123 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:40:17.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_134011_fixed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:40:17.000000Z
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, q=2-31, 3081 kb/s, 29.84 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:40:17.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 123 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:40:17.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #1:0 -> #0:0 (copy)
#   Stream #1:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=    0 fps=0.0 q=-1.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=  142 fps=0.0 q=-1.0 Lsize=    1866kB time=00:00:04.90 bitrate=3114.9kbits/s speed= 834x
# video:1785kB audio:74kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.345821%
#
# ffmpeg -i F:\Zdjęcia\Wrak_Race\20150913_134024.mp4 -i D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_134024.mp4 -map 1 -map_metadata 0 -c copy D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_134024_fixed.mp4
#
# ffmpeg version 6.0-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'F:\ZdjÄ™cia\Wrak_Race\20150913_134024.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:40:30.000000Z
#   Duration: 00:00:05.08, start: 0.000000, bitrate: 3067 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3077 kb/s, 29.78 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:40:30.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 124 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:40:30.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_134024.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:40:30.000000Z
#   Duration: 00:00:05.08, start: 0.000000, bitrate: 3067 kb/s
#   Stream #1:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3077 kb/s, 29.78 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:40:30.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #1:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 124 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:40:30.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_134024_fixed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:40:30.000000Z
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, q=2-31, 3077 kb/s, 29.78 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:40:30.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 124 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:40:30.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #1:0 -> #0:0 (copy)
#   Stream #1:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=    0 fps=0.0 q=-1.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=N/A
# frame=  145 fps=0.0 q=-1.0 Lsize=    1904kB time=00:00:05.05 bitrate=3085.3kbits/s speed= 341x
# video:1821kB audio:77kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.343139%
#
# ffmpeg -i F:\Zdjęcia\Wrak_Race\20150913_134035.mp4 -i D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_134035.mp4 -map 1 -map_metadata 0 -c copy D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_134035_fixed.mp4
#
# ffmpeg version 6.0-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'F:\ZdjÄ™cia\Wrak_Race\20150913_134035.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:41:04.000000Z
#   Duration: 00:00:27.58, start: 0.000000, bitrate: 3183 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3074 kb/s, 29.91 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:41:04.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 124 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:41:04.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_134035.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:41:04.000000Z
#   Duration: 00:00:27.58, start: 0.000000, bitrate: 3183 kb/s
#   Stream #1:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3074 kb/s, 29.91 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:41:04.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #1:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 124 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:41:04.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_134035_fixed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:41:04.000000Z
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, q=2-31, 3074 kb/s, 29.91 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:41:04.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 124 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:41:04.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #1:0 -> #0:0 (copy)
#   Stream #1:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=    0 fps=0.0 q=-1.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=N/A
# frame=  820 fps=0.0 q=-1.0 Lsize=   10734kB time=00:00:27.56 bitrate=3190.2kbits/s speed= 204x
# video:10283kB audio:420kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.285805%
#
# ffmpeg -i F:\Zdjęcia\Wrak_Race\20150913_134942.mp4 -i D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_134942.mp4 -map 1 -map_metadata 0 -c copy D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_134942_fixed.mp4
#
# ffmpeg version 6.0-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'F:\ZdjÄ™cia\Wrak_Race\20150913_134942.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:50:45.000000Z
#   Duration: 00:01:01.16, start: 0.000000, bitrate: 3196 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3070 kb/s, 29.93 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:50:45.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:50:45.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_134942.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:50:45.000000Z
#   Duration: 00:01:01.16, start: 0.000000, bitrate: 3196 kb/s
#   Stream #1:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3070 kb/s, 29.93 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:50:45.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #1:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:50:45.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_134942_fixed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T11:50:45.000000Z
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, q=2-31, 3070 kb/s, 29.93 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:50:45.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T11:50:45.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #1:0 -> #0:0 (copy)
#   Stream #1:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=    0 fps=0.0 q=-1.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=N/A
# frame= 1826 fps=0.0 q=-1.0 Lsize=   23895kB time=00:01:01.14 bitrate=3201.4kbits/s speed= 225x
# video:22870kB audio:958kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.278817%
#
# ffmpeg -i F:\Zdjęcia\Wrak_Race\20150913_141625.mp4 -i D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_141625.mp4 -map 1 -map_metadata 0 -c copy D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_141625_fixed.mp4
#
# ffmpeg version 6.0-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'F:\ZdjÄ™cia\Wrak_Race\20150913_141625.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T12:16:40.000000Z
#   Duration: 00:00:14.36, start: 0.000000, bitrate: 3155 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3081 kb/s, 29.91 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T12:16:40.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 123 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T12:16:40.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_141625.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T12:16:40.000000Z
#   Duration: 00:00:14.36, start: 0.000000, bitrate: 3155 kb/s
#   Stream #1:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3081 kb/s, 29.91 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T12:16:40.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #1:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 123 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T12:16:40.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_141625_fixed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T12:16:40.000000Z
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, q=2-31, 3081 kb/s, 29.91 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T12:16:40.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 123 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T12:16:40.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #1:0 -> #0:0 (copy)
#   Stream #1:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=    0 fps=0.0 q=-1.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=N/A
# frame=  422 fps=0.0 q=-1.0 Lsize=    5537kB time=00:00:14.33 bitrate=3164.2kbits/s speed= 267x
# video:5304kB audio:217kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.296672%
#
# ffmpeg -i F:\Zdjęcia\Wrak_Race\20150913_152724.mp4 -i D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_152724.mp4 -map 1 -map_metadata 0 -c copy D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_152724_fixed.mp4
#
# ffmpeg version 6.0-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'F:\ZdjÄ™cia\Wrak_Race\20150913_152724.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T13:27:40.000000Z
#   Duration: 00:00:15.34, start: 0.000000, bitrate: 3162 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3076 kb/s, 29.80 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:27:40.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:27:40.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_152724.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T13:27:40.000000Z
#   Duration: 00:00:15.34, start: 0.000000, bitrate: 3162 kb/s
#   Stream #1:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3076 kb/s, 29.80 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:27:40.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #1:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:27:40.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_152724_fixed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T13:27:40.000000Z
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, q=2-31, 3076 kb/s, 29.80 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:27:40.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:27:40.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #1:0 -> #0:0 (copy)
#   Stream #1:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=    0 fps=0.0 q=-1.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=N/A
# frame=  451 fps=0.0 q=-1.0 Lsize=    5929kB time=00:00:15.31 bitrate=3171.0kbits/s speed= 265x
# video:5672kB audio:240kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.294834%
#
# ffmpeg -i F:\Zdjęcia\Wrak_Race\20150913_152818.mp4 -i D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_152818.mp4 -map 1 -map_metadata 0 -c copy D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_152818_fixed.mp4
#
# ffmpeg version 6.0-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'F:\ZdjÄ™cia\Wrak_Race\20150913_152818.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T13:29:11.000000Z
#   Duration: 00:00:52.35, start: 0.000000, bitrate: 3177 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3057 kb/s, 29.78 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:29:11.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:29:11.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_152818.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T13:29:11.000000Z
#   Duration: 00:00:52.35, start: 0.000000, bitrate: 3177 kb/s
#   Stream #1:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3057 kb/s, 29.78 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:29:11.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #1:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:29:11.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_152818_fixed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T13:29:11.000000Z
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, q=2-31, 3057 kb/s, 29.78 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:29:11.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:29:11.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #1:0 -> #0:0 (copy)
#   Stream #1:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=    0 fps=0.0 q=-1.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=N/A
# frame= 1553 fps=0.0 q=-1.0 Lsize=   20332kB time=00:00:52.33 bitrate=3182.8kbits/s speed= 211x
# video:19454kB audio:821kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.279843%
#
# ffmpeg -i F:\Zdjęcia\Wrak_Race\20150913_153214.mp4 -i D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_153214.mp4 -map 1 -map_metadata 0 -c copy D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_153214_fixed.mp4
#
# ffmpeg version 6.0-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'F:\ZdjÄ™cia\Wrak_Race\20150913_153214.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T13:33:16.000000Z
#   Duration: 00:01:00.82, start: 0.000000, bitrate: 3183 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3071 kb/s, 29.91 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:33:16.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 124 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:33:16.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_153214.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T13:33:16.000000Z
#   Duration: 00:01:00.82, start: 0.000000, bitrate: 3183 kb/s
#   Stream #1:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3071 kb/s, 29.91 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:33:16.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #1:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 124 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:33:16.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_153214_fixed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T13:33:16.000000Z
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, q=2-31, 3071 kb/s, 29.91 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:33:16.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 124 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:33:16.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #1:0 -> #0:0 (copy)
#   Stream #1:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=    0 fps=0.0 q=-1.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=N/A
# frame= 1809 fps=0.0 q=-1.0 Lsize=   23669kB time=00:01:00.81 bitrate=3188.4kbits/s speed= 208x
# video:22676kB audio:928kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.278416%
#
# ffmpeg -i F:\Zdjęcia\Wrak_Race\20150913_155238.mp4 -i D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_155238.mp4 -map 1 -map_metadata 0 -c copy D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_155238_fixed.mp4
#
# ffmpeg version 6.0-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'F:\ZdjÄ™cia\Wrak_Race\20150913_155238.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T13:53:27.000000Z
#   Duration: 00:00:47.40, start: 0.000000, bitrate: 3194 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3073 kb/s, 29.92 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:53:27.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:53:27.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_155238.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T13:53:27.000000Z
#   Duration: 00:00:47.40, start: 0.000000, bitrate: 3194 kb/s
#   Stream #1:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3073 kb/s, 29.92 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:53:27.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #1:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:53:27.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_155238_fixed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T13:53:27.000000Z
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, q=2-31, 3073 kb/s, 29.92 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:53:27.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T13:53:27.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #1:0 -> #0:0 (copy)
#   Stream #1:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=    0 fps=0.0 q=-1.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame= 1413 fps=0.0 q=-1.0 Lsize=   18509kB time=00:00:47.38 bitrate=3200.2kbits/s speed= 204x
# video:17713kB audio:745kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.279735%
#
# ffmpeg -i F:\Zdjęcia\Wrak_Race\20150913_160321.mp4 -i D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_160321.mp4 -map 1 -map_metadata 0 -c copy D:\Windows\Pulpit\Zdjęcia\heif\Wrak_Race_heif\20150913_160321_fixed.mp4
#
# ffmpeg version 6.0-full_build-www.gyan.dev Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 12.2.0 (Rev10, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libvpl --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      58.  2.100 / 58.  2.100
#   libavcodec     60.  3.100 / 60.  3.100
#   libavformat    60.  3.100 / 60.  3.100
#   libavdevice    60.  1.100 / 60.  1.100
#   libavfilter     9.  3.100 /  9.  3.100
#   libswscale      7.  1.100 /  7.  1.100
#   libswresample   4. 10.100 /  4. 10.100
#   libpostproc    57.  1.100 / 57.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'F:\ZdjÄ™cia\Wrak_Race\20150913_160321.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T14:03:35.000000Z
#   Duration: 00:00:13.16, start: 0.000000, bitrate: 3156 kb/s
#   Stream #0:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3072 kb/s, 29.80 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T14:03:35.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 124 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T14:03:35.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_160321.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T14:03:35.000000Z
#   Duration: 00:00:13.16, start: 0.000000, bitrate: 3156 kb/s
#   Stream #1:0[0x1](eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, 3072 kb/s, 29.80 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T14:03:35.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #1:1[0x2](eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 124 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T14:03:35.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Output #0, mp4, to 'D:\Windows\Pulpit\ZdjÄ™cia\heif\Wrak_Race_heif\20150913_160321_fixed.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: isom3gp4
#     creation_time   : 2015-09-13T14:03:35.000000Z
#     encoder         : Lavf60.3.100
#   Stream #0:0(eng): Video: h264 (Baseline) (avc1 / 0x31637661), yuv420p(progressive), 640x480, q=2-31, 3072 kb/s, 29.80 fps, 29.92 tbr, 90k tbn (default)
#     Metadata:
#       creation_time   : 2015-09-13T14:03:35.000000Z
#       handler_name    : VideoHandle
#       vendor_id       : [0][0][0][0]
#       encoder         :
#   Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 124 kb/s (default)
#     Metadata:
#       creation_time   : 2015-09-13T14:03:35.000000Z
#       handler_name    : SoundHandle
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #1:0 -> #0:0 (copy)
#   Stream #1:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=    0 fps=0.0 q=-1.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=  387 fps=0.0 q=-1.0 Lsize=    5079kB time=00:00:13.14 bitrate=3166.2kbits/s speed= 168x
# video:4864kB audio:200kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.299375%

# %%
rn_path = Path(r'F:\Zdjęcia\Tor')
for file in rn_path.iterdir():
    if file.suffix == '.mp4':
        shutil.move(file, file.with_stem(file.stem.upper().replace(' ', '_')))
